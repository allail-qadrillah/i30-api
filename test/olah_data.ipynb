# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv('history.csv')
df.sample(5)
# Out:
#                       name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 104  Banda Aceh, Indonesia  2023-04-15     33.3     11.0  26.8          39.4
# 61   Banda Aceh, Indonesia  2023-03-03     29.2     24.6  26.2          32.4
# 38   Banda Aceh, Indonesia  2023-02-08     30.0     23.8  26.2          35.0
# 25   Banda Aceh, Indonesia  2023-01-26     29.0     23.1  25.2          32.8
# 130  Banda Aceh, Indonesia  2023-05-11     34.8     23.7  28.5          43.8
#
#      feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 104          11.0       29.2  21.9      75.4  ...         24.4       10
# 61           24.6       26.6  21.5      76.1  ...          8.5        5
# 38           23.8       27.4  22.7      81.4  ...         21.3        9
# 25           23.1       25.8  22.1      83.8  ...         17.9        9
# 130          23.7       31.9  23.0      72.4  ...         24.7        9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              152 non-null    object
#  1   datetime          152 non-null    object
#  2   tempmax           152 non-null    float64
#  3   tempmin           152 non-null    float64
#  4   temp              152 non-null    float64
#  5   feelslikemax      152 non-null    float64
#  6   feelslikemin      152 non-null    float64
#  7   feelslike         152 non-null    float64
#  8   dew               152 non-null    float64
#  9   humidity          152 non-null    float64
#  10  precip            152 non-null    float64
#  11  precipprob        152 non-null    int64
#  12  precipcover       152 non-null    float64
#  13  preciptype        142 non-null    object
#  14  snow              152 non-null    int64
#  15  snowdepth         152 non-null    int64
# ...

# %%
#datetime, temp, feels_like, conditions
selected_columns = ['datetime', 'temp', 'feelslike', 'conditions']
df2 = df[selected_columns]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    152 non-null    object
#  1   temp        152 non-null    float64
#  2   feelslike   152 non-null    float64
#  3   conditions  152 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 4.9+ KB

# %%
def print_all_unique_col_values(df):
  for column in df:
      print(f"{column} : {df[column].unique()}")


def print_object_unique_col_values(df):
  for column in df:
    if df[column].dtypes == 'object':
      print(f"{column} : {df[column].unique()}")


print_object_unique_col_values(df2)
# Out:
# datetime : ['2023-01-01' '2023-01-02' '2023-01-03' '2023-01-04' '2023-01-05'
#  '2023-01-06' '2023-01-07' '2023-01-08' '2023-01-09' '2023-01-10'
#  '2023-01-11' '2023-01-12' '2023-01-13' '2023-01-14' '2023-01-15'
#  '2023-01-16' '2023-01-17' '2023-01-18' '2023-01-19' '2023-01-20'
#  '2023-01-21' '2023-01-22' '2023-01-23' '2023-01-24' '2023-01-25'
#  '2023-01-26' '2023-01-27' '2023-01-28' '2023-01-29' '2023-01-30'
#  '2023-01-31' '2023-02-01' '2023-02-02' '2023-02-03' '2023-02-04'
#  '2023-02-05' '2023-02-06' '2023-02-07' '2023-02-08' '2023-02-09'
#  '2023-02-10' '2023-02-11' '2023-02-12' '2023-02-13' '2023-02-14'
#  '2023-02-15' '2023-02-16' '2023-02-17' '2023-02-18' '2023-02-19'
#  '2023-02-20' '2023-02-21' '2023-02-22' '2023-02-23' '2023-02-24'
#  '2023-02-25' '2023-02-26' '2023-02-27' '2023-02-28' '2023-03-01'
#  '2023-03-02' '2023-03-03' '2023-03-04' '2023-03-05' '2023-03-06'
#  '2023-03-07' '2023-03-08' '2023-03-09' '2023-03-10' '2023-03-11'
# ...

# %% [markdown]
# CONDITIONS = ['Rain, Partially cloudy' 'Partially cloudy' 'Rain, Overcast' 'Overcast'
#  'Clear']

# %%
df2.to_csv('weather_data_JanuarytoMei.csv', index=False)

# %%
df2.to_('weather_data_JanuarytoMei.xlsx', index=False)
